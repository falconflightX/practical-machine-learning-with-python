# %% [markdown]
# <a href="https://colab.research.google.com/github/falconflightX/practical-machine-learning-with-python/blob/master/Extracting_Stock_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install yfinance package.
# !pip install yfinance
 
# Import yfinance
import yfinance as yf

# %%
# Get the data for the stock 3M by specifying the stock ticker, start date, and end date
data = yf.download('MMM','2017-01-01','2019-08-20')
 
# Plot the close prices
import matplotlib.pyplot as plt
data.Close.plot()

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
